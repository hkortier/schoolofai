# %% [markdown]
# https://www.jgoertler.com/visual-exploration-gaussian-processes/
# http://www.gaussianprocess.org/gpml/

# %% [markdown]
# $$ p(y_{*} \mid y, X, x_{*}) $$

# %% [markdown]
# Bayesian inference
#
# # Bayes, ML, MAP

# %% [markdown]
# Gaussian distribution

# %% [markdown]
# Conditioning and Marginalization

# %% [markdown]
# Parametric vs Non-parameteric

# %% [markdown]
# Issues:
# - how to deploy]
# - O(n^3) O(n^2)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import numpy as np
import pandas as pd
import pymc3 as pm
import arviz as az

import warnings
warnings.simplefilter('ignore')
# Out:
# ---------------------------------------------------------------
# ModuleNotFoundError           Traceback (most recent call last)
# <ipython-input-41-d02696b7d0cc> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import pymc3 as pm
#       4 import arviz as az
#       5
#
# ModuleNotFoundError: No module named 'pymc3'

# %% [markdown]
# Central Limit Theorem

# %%
# seed the random number generator
np.random.seed(1)
# sample sizes
sizes = np.logspace(0,5,num=10000).astype(int)

sizes = 200*np.ones((10000,1)).astype(int)

# generate samples of different sizes and calculate their means
# means = [np.mean(np.random.rand(size)-.5) for size in sizes]
means = [np.mean(np.random.randint(low=1,high=6,size=size)) for size in sizes]
# print(means)
# plot sample mean error vs sample size
# plt.scatter(sizes, np.array(means))
# # plt.hist(np.array(means),bins=100)
# plt.show()

# %%
sns.distplot(np.array(means),);

# %% [markdown]
# But now with a very strange pdf, e.g. an unfair dice

# %%
from scipy import stats
xk = np.arange(6)
pk = (0.05, 0.2, 0,0 , 0.7, 0.05)
custm = stats.rv_discrete(name='custm', values=(xk, pk))

fig, ax = plt.subplots(1, 1)
ax.plot(xk, custm.pmf(xk), 'ro', ms=12, mec='r')
ax.vlines(xk, 0, custm.pmf(xk), colors='r', lw=4)
plt.show()

# %%
sizes = 200*np.ones((10000,1)).astype(int)
means = [np.mean(custm.rvs(size=size)) for size in sizes]

sns.distplot(np.array(means),);
